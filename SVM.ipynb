# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanathcharan/Data-Science-ExcelR/blob/main/SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Non_linear_SVM_Dataset.csv')
df
# Out:
#            X1        X2    Y
# 0    0.830858 -0.334342  1.0
# 1    0.991710  0.879000  0.0
# 2    1.107245 -0.470344  1.0
# 3   -0.140899  1.033148  0.0
# 4    0.405592  1.328529  0.0
# ..        ...       ...  ...
# 495  0.265123  1.023197  0.0
# 496  0.193576 -0.011663  1.0
# 497  0.345548 -0.128434  1.0
# 498  1.403890 -0.466993  1.0
# 499  0.075594  1.375965  0.0
#
# [500 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X1      500 non-null    float64
#  1   X2      500 non-null    float64
#  2   Y       500 non-null    float64
# dtypes: float64(3)
# memory usage: 11.8 KB

# %%
df.head()
# Out:
#          X1        X2    Y
# 0  0.830858 -0.334342  1.0
# 1  0.991710  0.879000  0.0
# 2  1.107245 -0.470344  1.0
# 3 -0.140899  1.033148  0.0
# 4  0.405592  1.328529  0.0

# %%
df.shape
# Out:
# (500, 3)

# %%
df.size
# Out:
# 1500

# %%
df.isnull().sum()
# Out:
# X1    0
# X2    0
# Y     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x='X1',y='X2',hue='Y',data=df)
plt.show()

# %%
x=df.drop(columns='Y')
y=df['Y']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=50)

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
svc=SVC()
svc.fit(x_train,y_train)
pred_train=svc.predict(x_train)
pred_test=svc.predict(x_test)
print("Test ACC: ",accuracy_score(y_train,pred_train))
print("Train ACC: ",accuracy_score(y_test,pred_test))
# Out:
# Test ACC:  0.9725
# Train ACC:  0.98

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
svc=SVC(kernel='linear')
svc.fit(x_train,y_train)
pred_train=svc.predict(x_train)
pred_test=svc.predict(x_test)
print("Test ACC: ",accuracy_score(y_train,pred_train))
print("Train ACC: ",accuracy_score(y_test,pred_test))
# Out:
# Test ACC:  0.8575
# Train ACC:  0.86

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
svc=SVC(kernel='poly')
svc.fit(x_train,y_train)
pred_train=svc.predict(x_train)
pred_test=svc.predict(x_test)
print("Test ACC: ",accuracy_score(y_train,pred_train))
print("Train ACC: ",accuracy_score(y_test,pred_test))
# Out:
# Test ACC:  0.9
# Train ACC:  0.89

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
svc=SVC(kernel='sigmoid')
svc.fit(x_train,y_train)
pred_train=svc.predict(x_train)
pred_test=svc.predict(x_test)
print("Test ACC: ",accuracy_score(y_train,pred_train))
print("Train ACC: ",accuracy_score(y_test,pred_test))
# Out:
# Test ACC:  0.6775
# Train ACC:  0.6

# %%
df=pd.read_csv('Pharma_Industry.csv')
df
# Out:
#      Drug Dosage (mg)  Systolic Blood Pressure (mmHg)  Heart Rate (BPM)  \
# 0           -0.128538                        0.303280         -1.881849
# 1           -1.846188                        2.865142         -0.929511
# 2           -1.252393                       -1.541613          0.363632
# 3            1.992515                       -1.142779         -0.766657
# 4            0.377100                        0.538410         -0.029263
# ..                ...                             ...               ...
# 495         -1.553759                        0.506938          0.817890
# 496          0.551476                        1.714321          0.340589
# 497         -1.072743                       -0.221137          0.239247
# 498          1.661259                        0.245759         -0.457096
# 499         -1.143726                        0.715320          0.108560
#
#      Liver Toxicity Index (U/L)  Blood Glucose Level (mg/dL)  Drug Response
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Drug Dosage (mg)                500 non-null    float64
#  1   Systolic Blood Pressure (mmHg)  500 non-null    float64
#  2   Heart Rate (BPM)                500 non-null    float64
#  3   Liver Toxicity Index (U/L)      500 non-null    float64
#  4   Blood Glucose Level (mg/dL)     500 non-null    float64
#  5   Drug Response                   500 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 23.6 KB

# %%
df.shape
# Out:
# (500, 6)

# %%
df.size
# Out:
# 3000

# %%
df.isnull().sum()
# Out:
# Drug Dosage (mg)                  0
# Systolic Blood Pressure (mmHg)    0
# Heart Rate (BPM)                  0
# Liver Toxicity Index (U/L)        0
# Blood Glucose Level (mg/dL)       0
# Drug Response                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
for i in df.select_dtypes(include=['int','float']).columns:
  q1=df[i].quantile(0.25)
  q3=df[i].quantile(0.75)
  iqr=q3-q1
  upper=q3+1.5*iqr
  lower=q1-1.5*iqr
  df[i]=df[i].clip(lower,upper)

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
x=df.drop(columns='Drug Response')
y=df['Drug Response']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=50)

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
svc=SVC()
svc.fit(x_train,y_train)
pred_train=svc.predict(x_train)
pred_test=svc.predict(x_test)
print("Test ACC: ",accuracy_score(y_train,pred_train))
print("Train ACC: ",accuracy_score(y_test,pred_test))
#
# Out:
# Test ACC:  0.795
# Train ACC:  0.8

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
svc=SVC(kernel='linear')
svc.fit(x_train,y_train)
pred_train=svc.predict(x_train)
pred_test=svc.predict(x_test)
print("Test ACC: ",accuracy_score(y_train,pred_train))
print("Train ACC: ",accuracy_score(y_test,pred_test))
# Out:
# Test ACC:  0.705
# Train ACC:  0.77

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
svc=SVC(kernel='poly')
svc.fit(x_train,y_train)
pred_train=svc.predict(x_train)
pred_test=svc.predict(x_test)
print("Test ACC: ",accuracy_score(y_train,pred_train))
print("Train ACC: ",accuracy_score(y_test,pred_test))
# Out:
# Test ACC:  0.7475
# Train ACC:  0.75

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
svc=SVC(kernel='sigmoid')
svc.fit(x_train,y_train)
pred_train=svc.predict(x_train)
pred_test=svc.predict(x_test)
print("Test ACC: ",accuracy_score(y_train,pred_train))
print("Train ACC: ",accuracy_score(y_test,pred_test))
# Out:
# Test ACC:  0.6275
# Train ACC:  0.63
